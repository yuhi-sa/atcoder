# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

# %%
def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/72.0,frames[0].shape[0]/72.0),dpi=72)
    
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    anim.save('movie_cartpole.mp4')
    display(display_animation(anim, default_mode='loop'))

# %%
#定数の設定
ENV = 'CartPole-v0' #使用する課題名
NUM_DIZITIZED = 6 #各状態の離散値への分割数
GAMMA = 0.99 #時間割引率
ETA = 0.5 #学習係数
MAX_STEPS = 200 #1試行のstep数
NUM_EPISODES = 1000 #最大試行回数

# %%
#エージェントクラス
class Agent:
    def __init__(self,num_states,num_actions):
        self.brain = Brain(num_states, num_actions)
        
    def update_Q_function(self, observation, action, reward, observation_next):
        #Q関数の更新
        self.brain.update_Q_table(observation, action, reward, observation_next)
        
    def get_action(self, observation, step):
        #行動の決定
        action = self.brain.decide_action(observation, step)
        return action

# %%
#エージェントがもつ頭脳となるクラス

class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
    
        #Qテーブルを作成する
        self.q_table = np.random.uniform(low=0, high=1, size=(NUM_DIZITIZED**num_states, num_actions))
        
    def bins(self,clip_min, clip_max, num):
        #観測したデータを離散値にするしきい値を求める
        return np.linspace(clip_min, clip_max, num+1)[1:-1]
    
    def digitize_state(self, observation):
        #観測したobservationを離散値に変換する
        cart_pos, cart_v, pole_angle, pole_v = observation
        
        digitized =[
            np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
            np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
            np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
            np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
        ]
        return sum([x*(NUM_DIZITIZED**i) for i, x in enumerate(digitized)])
    
    def update_Q_table(self, observation, action, reward, observation_next):
        #QテーブルをQ学習により更新
        state = self.digitize_state(observation) #状態を離散化
        state_next = self.digitize_state(observation_next) #次の状態を離散化
        Max_Q_next = max(self.q_table[state_next][:])
        self.q_table[state, action] = self.q_table[state, action] + \
        ETA *(reward + GAMMA * Max_Q_next - self.q_table[state, action])

    def decide_action(self, observation, episode):
        #epsilon-greedy法で徐々に最適行動を採用する
        state = self.digitize_state(observation)
        epsilon = 0.5*(1/(episode+1))
        
        if epsilon <= np.random.uniform(0, 1):
            action = np.argmax(self.q_table[state][:])
        else:
            action = np.random.choice(self.num_actions)
        return action

# %%
class Environment:

    def __init__(self):
        self.env = gym.make(ENV) #実行する課題を設定
        
        num_states = self.env.observation_space.shape[0] #課題の状態数を取得
        num_actions = self.env.action_space.n #行動取得
        self.agent = Agent(num_states, num_actions) #環境内で行動するAgent生成
        
    def run(self):
        #実行
        complete_episodes = 0 #195step以上連続で立ち続けた試行数
        is_episode_final = False #最終試行フラグ
        frames = [] #動画用の画像を格納する変数
        
        for episode in range(NUM_EPISODES): #試行数分繰り返す
            observation = self.env.reset() #環境の初期化
            
            for step in range(MAX_STEPS): #1エピソードのループ
                if is_episode_final is True:
                    frames.append(self.env.render(mode='rgb_array'))
                    
                #行動を求める
                action = self.agent.get_action(observation, episode)
                    
                #行動a_tに基づき， s_{t+1}，r_{t+1}を求める
                observation_next, _, done, _ = self.env.step(action) # reward と infoは使わない
                    
                #報酬を与える
                if done:
                    if step < 195:
                        reward = -1 #途中でこけたら罰則として報酬-1を与える
                        complete_episodes =0
                    else:
                        reward =1
                        complete_episodes += 1
                else:
                    reward = 0
                        
                #Q関数を更新する
                self.agent.update_Q_function(observation, action, reward, observation_next)
                    
                #観測の更新
                observation = observation_next
                    
                #終了時の処理
                if done:
                    print('{0} Episode: Finish after {1}time steps'.format(episode,step+1))
                    break
            if is_episode_final is True: #最終試行では動画を保存と描写
                display_fra
                mes_as_gif(frames)
                break
                
            if complete_episodes >= 10:
                print('10回連続成功')

# %%
#main
cartpole_env = Environment()
cartpole_env.run()
# Out:
# 0 Episode: Finish after 25time steps
# 1 Episode: Finish after 25time steps
# 2 Episode: Finish after 41time steps
# 3 Episode: Finish after 11time steps
# 4 Episode: Finish after 27time steps
# 5 Episode: Finish after 122time steps
# 6 Episode: Finish after 34time steps
# 7 Episode: Finish after 34time steps
# 8 Episode: Finish after 25time steps
# 9 Episode: Finish after 60time steps
# 10 Episode: Finish after 24time steps
# 11 Episode: Finish after 107time steps
# 12 Episode: Finish after 39time steps
# 13 Episode: Finish after 36time steps
# 14 Episode: Finish after 200time steps
# 15 Episode: Finish after 21time steps
# 16 Episode: Finish after 72time steps
# 17 Episode: Finish after 138time steps
# 18 Episode: Finish after 86time steps
# 19 Episode: Finish after 41time steps
# 20 Episode: Finish after 39time steps
# 21 Episode: Finish after 17time steps
# 22 Episode: Finish after 152time steps
# 23 Episode: Finish after 18time steps
# 24 Episode: Finish after 20time steps
# 25 Episode: Finish after 12time steps
# 26 Episode: Finish after 16time steps
# 27 Episode: Finish after 18time steps
# 28 Episode: Finish after 22time steps
# 29 Episode: Finish after 16time steps
# 30 Episode: Finish after 36time steps
# 31 Episode: Finish after 44time steps
# 32 Episode: Finish after 43time steps
# 33 Episode: Finish after 83time steps
# 34 Episode: Finish after 38time steps
# 35 Episode: Finish after 98time steps
# 36 Episode: Finish after 12time steps
# 37 Episode: Finish after 43time steps
# 38 Episode: Finish after 27time steps
# 39 Episode: Finish after 12time steps
# 40 Episode: Finish after 31time steps
# 41 Episode: Finish after 53time steps
# 42 Episode: Finish after 16time steps
# 43 Episode: Finish after 143time steps
# 44 Episode: Finish after 23time steps
# 45 Episode: Finish after 28time steps
# 46 Episode: Finish after 151time steps
# 47 Episode: Finish after 29time steps
# 48 Episode: Finish after 200time steps
# 49 Episode: Finish after 105time steps
# 50 Episode: Finish after 31time steps
# 51 Episode: Finish after 123time steps
# 52 Episode: Finish after 65time steps
# 53 Episode: Finish after 17time steps
# 54 Episode: Finish after 79time steps
# 55 Episode: Finish after 43time steps
# 56 Episode: Finish after 105time steps
# 57 Episode: Finish after 67time steps
# 58 Episode: Finish after 22time steps
# 59 Episode: Finish after 44time steps
# 60 Episode: Finish after 49time steps
# 61 Episode: Finish after 200time steps
# 62 Episode: Finish after 171time steps
# 63 Episode: Finish after 200time steps
# 64 Episode: Finish after 200time steps
# 65 Episode: Finish after 123time steps
# 66 Episode: Finish after 26time steps
# 67 Episode: Finish after 32time steps
# 68 Episode: Finish after 16time steps
# 69 Episode: Finish after 48time steps
# 70 Episode: Finish after 12time steps
# 71 Episode: Finish after 200time steps
# 72 Episode: Finish after 200time steps
# 73 Episode: Finish after 112time steps
# 74 Episode: Finish after 30time steps
# 75 Episode: Finish after 200time steps
# 76 Episode: Finish after 109time steps
# 77 Episode: Finish after 47time steps
# 78 Episode: Finish after 168time steps
# 79 Episode: Finish after 149time steps
# 80 Episode: Finish after 200time steps
# 81 Episode: Finish after 200time steps
# 82 Episode: Finish after 129time steps
# 83 Episode: Finish after 200time steps
# 84 Episode: Finish after 152time steps
# 85 Episode: Finish after 200time steps
# 86 Episode: Finish after 200time steps
# 87 Episode: Finish after 200time steps
# 88 Episode: Finish after 200time steps
# 89 Episode: Finish after 39time steps
# 90 Episode: Finish after 200time steps
# 91 Episode: Finish after 200time steps
# 92 Episode: Finish after 66time steps
# 93 Episode: Finish after 200time steps
# 94 Episode: Finish after 151time steps
# 95 Episode: Finish after 55time steps
# 96 Episode: Finish after 49time steps
# 97 Episode: Finish after 10time steps
# 98 Episode: Finish after 18time steps
# 99 Episode: Finish after 64time steps
# 100 Episode: Finish after 55time steps
# 101 Episode: Finish after 82time steps
# 102 Episode: Finish after 47time steps
# 103 Episode: Finish after 148time steps
# 104 Episode: Finish after 10time steps
# 105 Episode: Finish after 13time steps
# 106 Episode: Finish after 36time steps
# 107 Episode: Finish after 200time steps
# 108 Episode: Finish after 151time steps
# 109 Episode: Finish after 200time steps
# 110 Episode: Finish after 200time steps
# 111 Episode: Finish after 11time steps
# 112 Episode: Finish after 104time steps
# 113 Episode: Finish after 127time steps
# 114 Episode: Finish after 114time steps
# 115 Episode: Finish after 117time steps
# 116 Episode: Finish after 200time steps
# 117 Episode: Finish after 92time steps
# 118 Episode: Finish after 11time steps
# 119 Episode: Finish after 67time steps
# 120 Episode: Finish after 118time steps
# 121 Episode: Finish after 117time steps
# 122 Episode: Finish after 122time steps
# 123 Episode: Finish after 179time steps
# 124 Episode: Finish after 127time steps
# 125 Episode: Finish after 179time steps
# 126 Episode: Finish after 11time steps
# 127 Episode: Finish after 40time steps
# 128 Episode: Finish after 200time steps
# 129 Episode: Finish after 126time steps
# 130 Episode: Finish after 148time steps
# 131 Episode: Finish after 200time steps
# 132 Episode: Finish after 200time steps
# 133 Episode: Finish after 167time steps
# 134 Episode: Finish after 200time steps
# 135 Episode: Finish after 200time steps
# 136 Episode: Finish after 80time steps
# 137 Episode: Finish after 175time steps
# 138 Episode: Finish after 200time steps
# 139 Episode: Finish after 175time steps
# 140 Episode: Finish after 200time steps
# 141 Episode: Finish after 200time steps
# 142 Episode: Finish after 131time steps
# 143 Episode: Finish after 146time steps
# 144 Episode: Finish after 183time steps
# 145 Episode: Finish after 150time steps
# 146 Episode: Finish after 185time steps
# 147 Episode: Finish after 177time steps
# 148 Episode: Finish after 200time steps
# 149 Episode: Finish after 146time steps
# 150 Episode: Finish after 200time steps
# 151 Episode: Finish after 200time steps
# 152 Episode: Finish after 163time steps
# 153 Episode: Finish after 160time steps
# 154 Episode: Finish after 200time steps
# 155 Episode: Finish after 183time steps
# 156 Episode: Finish after 124time steps
# 157 Episode: Finish after 171time steps
# 158 Episode: Finish after 200time steps
# 159 Episode: Finish after 151time steps
# 160 Episode: Finish after 114time steps
# 161 Episode: Finish after 158time steps
# 162 Episode: Finish after 200time steps
# 163 Episode: Finish after 194time steps
# 164 Episode: Finish after 200time steps
# 165 Episode: Finish after 132time steps
# 166 Episode: Finish after 133time steps
# 167 Episode: Finish after 100time steps
# 168 Episode: Finish after 199time steps
# 169 Episode: Finish after 175time steps
# 170 Episode: Finish after 200time steps
# 171 Episode: Finish after 31time steps
# 172 Episode: Finish after 132time steps
# 173 Episode: Finish after 56time steps
# 174 Episode: Finish after 184time steps
# 175 Episode: Finish after 152time steps
# 176 Episode: Finish after 176time steps
# 177 Episode: Finish after 200time steps
# 178 Episode: Finish after 200time steps
# 179 Episode: Finish after 200time steps
# 180 Episode: Finish after 200time steps
# 181 Episode: Finish after 66time steps
# 182 Episode: Finish after 200time steps
# 183 Episode: Finish after 182time steps
# 184 Episode: Finish after 200time steps
# 185 Episode: Finish after 74time steps
# 186 Episode: Finish after 151time steps
# 187 Episode: Finish after 144time steps
# 188 Episode: Finish after 200time steps
# 189 Episode: Finish after 30time steps
# 190 Episode: Finish after 110time steps
# 191 Episode: Finish after 101time steps
# 192 Episode: Finish after 200time steps
# 193 Episode: Finish after 200time steps
# 194 Episode: Finish after 200time steps
# 195 Episode: Finish after 200time steps
# 196 Episode: Finish after 200time steps
# 197 Episode: Finish after 200time steps
# 198 Episode: Finish after 105time steps
# 199 Episode: Finish after 200time steps
# 200 Episode: Finish after 156time steps
# 201 Episode: Finish after 200time steps
# 202 Episode: Finish after 170time steps
# 203 Episode: Finish after 200time steps
# 204 Episode: Finish after 177time steps
# 205 Episode: Finish after 200time steps
# 206 Episode: Finish after 200time steps
# 207 Episode: Finish after 200time steps
# 208 Episode: Finish after 200time steps
# 209 Episode: Finish after 92time steps
# 210 Episode: Finish after 158time steps
# 211 Episode: Finish after 200time steps
# 212 Episode: Finish after 150time steps
# 213 Episode: Finish after 28time steps
# 214 Episode: Finish after 160time steps
# 215 Episode: Finish after 200time steps
# 216 Episode: Finish after 200time steps
# 217 Episode: Finish after 200time steps
# 218 Episode: Finish after 159time steps
# 219 Episode: Finish after 182time steps
# 220 Episode: Finish after 191time steps
# 221 Episode: Finish after 200time steps
# 222 Episode: Finish after 107time steps
# 223 Episode: Finish after 116time steps
# 224 Episode: Finish after 200time steps
# 225 Episode: Finish after 200time steps
# 226 Episode: Finish after 200time steps
# 227 Episode: Finish after 200time steps
# 228 Episode: Finish after 200time steps
# 229 Episode: Finish after 200time steps
# 230 Episode: Finish after 200time steps
# 231 Episode: Finish after 200time steps
# 232 Episode: Finish after 200time steps
# 233 Episode: Finish after 200time steps
# 10回連続成功
# 234 Episode: Finish after 200time steps
# 10回連続成功
# 235 Episode: Finish after 200time steps
# 10回連続成功
# 236 Episode: Finish after 200time steps
# 10回連続成功
# 237 Episode: Finish after 200time steps
# 10回連続成功
# 238 Episode: Finish after 200time steps
# 10回連続成功
# 239 Episode: Finish after 200time steps
# 10回連続成功
# 240 Episode: Finish after 200time steps
# 10回連続成功
# 241 Episode: Finish after 200time steps
# 10回連続成功
# 242 Episode: Finish after 200time steps
# 10回連続成功
# 243 Episode: Finish after 200time steps
# 10回連続成功
# 244 Episode: Finish after 200time steps
# 10回連続成功
# 245 Episode: Finish after 200time steps
# 10回連続成功
# 246 Episode: Finish after 200time steps
# 10回連続成功
# 247 Episode: Finish after 200time steps
# 10回連続成功
# 248 Episode: Finish after 200time steps
# 10回連続成功
# 249 Episode: Finish after 200time steps
# 10回連続成功
# 250 Episode: Finish after 200time steps
# 10回連続成功
# 251 Episode: Finish after 200time steps
# 10回連続成功
# 252 Episode: Finish after 200time steps
# 10回連続成功
# 253 Episode: Finish after 200time steps
# 10回連続成功
# 254 Episode: Finish after 200time steps
# 10回連続成功
# 255 Episode: Finish after 200time steps
# 10回連続成功
# 256 Episode: Finish after 200time steps
# 10回連続成功
# 257 Episode: Finish after 200time steps
# 10回連続成功
# 258 Episode: Finish after 200time steps
# 10回連続成功
# 259 Episode: Finish after 200time steps
# 10回連続成功
# 260 Episode: Finish after 200time steps
# 10回連続成功
# 261 Episode: Finish after 200time steps
# 10回連続成功
# 262 Episode: Finish after 200time steps
# 10回連続成功
# 263 Episode: Finish after 200time steps
# 10回連続成功
# 264 Episode: Finish after 200time steps
# 10回連続成功
# 265 Episode: Finish after 200time steps
# 10回連続成功
# 266 Episode: Finish after 200time steps
# 10回連続成功
# 267 Episode: Finish after 200time steps
# 10回連続成功
# 268 Episode: Finish after 200time steps
# 10回連続成功
# 269 Episode: Finish after 200time steps
# 10回連続成功
# 270 Episode: Finish after 200time steps
# 10回連続成功
# 271 Episode: Finish after 200time steps
# 10回連続成功
# 272 Episode: Finish after 200time steps
# 10回連続成功
# 273 Episode: Finish after 200time steps
# 10回連続成功
# 274 Episode: Finish after 200time steps
# 10回連続成功
# 275 Episode: Finish after 200time steps
# 10回連続成功
# 276 Episode: Finish after 200time steps
# 10回連続成功
# 277 Episode: Finish after 200time steps
# 10回連続成功
# 278 Episode: Finish after 200time steps
# 10回連続成功
# 279 Episode: Finish after 200time steps
# 10回連続成功
# 280 Episode: Finish after 200time steps
# 10回連続成功
# 281 Episode: Finish after 200time steps
# 10回連続成功
# 282 Episode: Finish after 200time steps
# 10回連続成功
# 283 Episode: Finish after 200time steps
# 10回連続成功
# 284 Episode: Finish after 200time steps
# 10回連続成功
# 285 Episode: Finish after 200time steps
# 10回連続成功
# 286 Episode: Finish after 200time steps
# 10回連続成功
# 287 Episode: Finish after 167time steps
# 288 Episode: Finish after 200time steps
# 289 Episode: Finish after 200time steps
# 290 Episode: Finish after 200time steps
# 291 Episode: Finish after 200time steps
# 292 Episode: Finish after 200time steps
# 293 Episode: Finish after 200time steps
# 294 Episode: Finish after 200time steps
# 295 Episode: Finish after 200time steps
# 296 Episode: Finish after 200time steps
# 297 Episode: Finish after 200time steps
# 10回連続成功
# 298 Episode: Finish after 200time steps
# 10回連続成功
# 299 Episode: Finish after 200time steps
# 10回連続成功
# 300 Episode: Finish after 200time steps
# 10回連続成功
# 301 Episode: Finish after 200time steps
# 10回連続成功
# 302 Episode: Finish after 200time steps
# 10回連続成功
# 303 Episode: Finish after 200time steps
# 10回連続成功
# 304 Episode: Finish after 200time steps
# 10回連続成功
# 305 Episode: Finish after 177time steps
# 306 Episode: Finish after 200time steps
# 307 Episode: Finish after 200time steps
# 308 Episode: Finish after 200time steps
# 309 Episode: Finish after 200time steps
# 310 Episode: Finish after 200time steps
# 311 Episode: Finish after 90time steps
# 312 Episode: Finish after 200time steps
# 313 Episode: Finish after 200time steps
# 314 Episode: Finish after 200time steps
# 315 Episode: Finish after 200time steps
# 316 Episode: Finish after 190time steps
# 317 Episode: Finish after 200time steps
# 318 Episode: Finish after 200time steps
# 319 Episode: Finish after 200time steps
# 320 Episode: Finish after 200time steps
# 321 Episode: Finish after 200time steps
# 322 Episode: Finish after 200time steps
# 323 Episode: Finish after 200time steps
# 324 Episode: Finish after 200time steps
# 325 Episode: Finish after 200time steps
# 326 Episode: Finish after 200time steps
# 10回連続成功
# 327 Episode: Finish after 200time steps
# 10回連続成功
# 328 Episode: Finish after 200time steps
# 10回連続成功
# 329 Episode: Finish after 200time steps
# 10回連続成功
# 330 Episode: Finish after 200time steps
# 10回連続成功
# 331 Episode: Finish after 200time steps
# 10回連続成功
# 332 Episode: Finish after 200time steps
# 10回連続成功
# 333 Episode: Finish after 200time steps
# 10回連続成功
# 334 Episode: Finish after 200time steps
# 10回連続成功
# 335 Episode: Finish after 200time steps
# 10回連続成功
# 336 Episode: Finish after 200time steps
# 10回連続成功
# 337 Episode: Finish after 200time steps
# 10回連続成功
# 338 Episode: Finish after 200time steps
# 10回連続成功
# 339 Episode: Finish after 200time steps
# 10回連続成功
# 340 Episode: Finish after 200time steps
# 10回連続成功
# 341 Episode: Finish after 200time steps
# 10回連続成功
# 342 Episode: Finish after 200time steps
# 10回連続成功
# 343 Episode: Finish after 200time steps
# 10回連続成功
# 344 Episode: Finish after 200time steps
# 10回連続成功
# 345 Episode: Finish after 200time steps
# 10回連続成功
# 346 Episode: Finish after 200time steps
# 10回連続成功
# 347 Episode: Finish after 200time steps
# 10回連続成功
# 348 Episode: Finish after 200time steps
# 10回連続成功
# 349 Episode: Finish after 200time steps
# 10回連続成功
# 350 Episode: Finish after 200time steps
# 10回連続成功
# 351 Episode: Finish after 200time steps
# 10回連続成功
# 352 Episode: Finish after 200time steps
# 10回連続成功
# 353 Episode: Finish after 200time steps
# 10回連続成功
# 354 Episode: Finish after 200time steps
# 10回連続成功
# 355 Episode: Finish after 200time steps
# 10回連続成功
# 356 Episode: Finish after 200time steps
# 10回連続成功
# 357 Episode: Finish after 200time steps
# 10回連続成功
# 358 Episode: Finish after 200time steps
# 10回連続成功
# 359 Episode: Finish after 200time steps
# 10回連続成功
# 360 Episode: Finish after 200time steps
# 10回連続成功
# 361 Episode: Finish after 200time steps
# 10回連続成功
# 362 Episode: Finish after 200time steps
# 10回連続成功
# 363 Episode: Finish after 132time steps
# 364 Episode: Finish after 104time steps
# 365 Episode: Finish after 200time steps
# 366 Episode: Finish after 200time steps
# 367 Episode: Finish after 200time steps
# 368 Episode: Finish after 200time steps
# 369 Episode: Finish after 200time steps
# 370 Episode: Finish after 200time steps
# 371 Episode: Finish after 200time steps
# 372 Episode: Finish after 200time steps
# 373 Episode: Finish after 200time steps
# 374 Episode: Finish after 200time steps
# 10回連続成功
# 375 Episode: Finish after 200time steps
# 10回連続成功
# 376 Episode: Finish after 200time steps
# 10回連続成功
# 377 Episode: Finish after 200time steps
# 10回連続成功
# 378 Episode: Finish after 200time steps
# 10回連続成功
# 379 Episode: Finish after 200time steps
# 10回連続成功
# 380 Episode: Finish after 200time steps
# 10回連続成功
# 381 Episode: Finish after 200time steps
# 10回連続成功
# 382 Episode: Finish after 200time steps
# 10回連続成功
# 383 Episode: Finish after 200time steps
# 10回連続成功
# 384 Episode: Finish after 200time steps
# 10回連続成功
# 385 Episode: Finish after 200time steps
# 10回連続成功
# 386 Episode: Finish after 200time steps
# 10回連続成功
# 387 Episode: Finish after 200time steps
# 10回連続成功
# 388 Episode: Finish after 200time steps
# 10回連続成功
# 389 Episode: Finish after 200time steps
# 10回連続成功
# 390 Episode: Finish after 200time steps
# 10回連続成功
# 391 Episode: Finish after 200time steps
# 10回連続成功
# 392 Episode: Finish after 200time steps
# 10回連続成功
# 393 Episode: Finish after 200time steps
# 10回連続成功
# 394 Episode: Finish after 200time steps
# 10回連続成功
# 395 Episode: Finish after 200time steps
# 10回連続成功
# 396 Episode: Finish after 200time steps
# 10回連続成功
# 397 Episode: Finish after 200time steps
# 10回連続成功
# 398 Episode: Finish after 200time steps
# 10回連続成功
# 399 Episode: Finish after 200time steps
# 10回連続成功
# 400 Episode: Finish after 200time steps
# 10回連続成功
# 401 Episode: Finish after 181time steps
# 402 Episode: Finish after 200time steps
# 403 Episode: Finish after 200time steps
# 404 Episode: Finish after 176time steps
# 405 Episode: Finish after 200time steps
# 406 Episode: Finish after 200time steps
# 407 Episode: Finish after 200time steps
# 408 Episode: Finish after 200time steps
# 409 Episode: Finish after 200time steps
# 410 Episode: Finish after 200time steps
# 411 Episode: Finish after 200time steps
# 412 Episode: Finish after 183time steps
# 413 Episode: Finish after 200time steps
# 414 Episode: Finish after 200time steps
# 415 Episode: Finish after 200time steps
# 416 Episode: Finish after 200time steps
# 417 Episode: Finish after 200time steps
# 418 Episode: Finish after 200time steps
# 419 Episode: Finish after 200time steps
# 420 Episode: Finish after 200time steps
# 421 Episode: Finish after 200time steps
# 422 Episode: Finish after 200time steps
# 10回連続成功
# 423 Episode: Finish after 200time steps
# 10回連続成功
# 424 Episode: Finish after 200time steps
# 10回連続成功
# 425 Episode: Finish after 200time steps
# 10回連続成功
# 426 Episode: Finish after 200time steps
# 10回連続成功
# 427 Episode: Finish after 200time steps
# 10回連続成功
# 428 Episode: Finish after 200time steps
# 10回連続成功
# 429 Episode: Finish after 200time steps
# 10回連続成功
# 430 Episode: Finish after 200time steps
# 10回連続成功
# 431 Episode: Finish after 200time steps
# 10回連続成功
# 432 Episode: Finish after 200time steps
# 10回連続成功
# 433 Episode: Finish after 200time steps
# 10回連続成功
# 434 Episode: Finish after 200time steps
# 10回連続成功
# 435 Episode: Finish after 200time steps
# 10回連続成功
# 436 Episode: Finish after 200time steps
# 10回連続成功
# 437 Episode: Finish after 200time steps
# 10回連続成功
# 438 Episode: Finish after 200time steps
# 10回連続成功
# 439 Episode: Finish after 200time steps
# 10回連続成功
# 440 Episode: Finish after 200time steps
# 10回連続成功
# 441 Episode: Finish after 200time steps
# 10回連続成功
# 442 Episode: Finish after 200time steps
# 10回連続成功
# 443 Episode: Finish after 200time steps
# 10回連続成功
# 444 Episode: Finish after 200time steps
# 10回連続成功
# 445 Episode: Finish after 200time steps
# 10回連続成功
# 446 Episode: Finish after 200time steps
# 10回連続成功
# 447 Episode: Finish after 200time steps
# 10回連続成功
# 448 Episode: Finish after 200time steps
# 10回連続成功
# 449 Episode: Finish after 200time steps
# 10回連続成功
# 450 Episode: Finish after 200time steps
# 10回連続成功
# 451 Episode: Finish after 200time steps
# 10回連続成功
# 452 Episode: Finish after 197time steps
# 10回連続成功
# 453 Episode: Finish after 200time steps
# 10回連続成功
# 454 Episode: Finish after 200time steps
# 10回連続成功
# 455 Episode: Finish after 200time steps
# 10回連続成功
# 456 Episode: Finish after 200time steps
# 10回連続成功
# 457 Episode: Finish after 200time steps
# 10回連続成功
# 458 Episode: Finish after 200time steps
# 10回連続成功
# 459 Episode: Finish after 200time steps
# 10回連続成功
# 460 Episode: Finish after 200time steps
# 10回連続成功
# 461 Episode: Finish after 200time steps
# 10回連続成功
# 462 Episode: Finish after 200time steps
# 10回連続成功
# 463 Episode: Finish after 200time steps
# 10回連続成功
# 464 Episode: Finish after 200time steps
# 10回連続成功
# 465 Episode: Finish after 200time steps
# 10回連続成功
# 466 Episode: Finish after 200time steps
# 10回連続成功
# 467 Episode: Finish after 200time steps
# 10回連続成功
# 468 Episode: Finish after 200time steps
# 10回連続成功
# 469 Episode: Finish after 200time steps
# 10回連続成功
# 470 Episode: Finish after 200time steps
# 10回連続成功
# 471 Episode: Finish after 200time steps
# 10回連続成功
# 472 Episode: Finish after 200time steps
# 10回連続成功
# 473 Episode: Finish after 186time steps
# 474 Episode: Finish after 200time steps
# 475 Episode: Finish after 200time steps
# 476 Episode: Finish after 200time steps
# 477 Episode: Finish after 200time steps
# 478 Episode: Finish after 200time steps
# 479 Episode: Finish after 200time steps
# 480 Episode: Finish after 51time steps
# 481 Episode: Finish after 159time steps
# 482 Episode: Finish after 200time steps
# 483 Episode: Finish after 200time steps
# 484 Episode: Finish after 200time steps
# 485 Episode: Finish after 200time steps
# 486 Episode: Finish after 200time steps
# 487 Episode: Finish after 200time steps
# 488 Episode: Finish after 200time steps
# 489 Episode: Finish after 200time steps
# 490 Episode: Finish after 200time steps
# 491 Episode: Finish after 200time steps
# 10回連続成功
# 492 Episode: Finish after 200time steps
# 10回連続成功
# 493 Episode: Finish after 200time steps
# 10回連続成功
# 494 Episode: Finish after 200time steps
# 10回連続成功
# 495 Episode: Finish after 200time steps
# 10回連続成功
# 496 Episode: Finish after 200time steps
# 10回連続成功
# 497 Episode: Finish after 200time steps
# 10回連続成功
# 498 Episode: Finish after 200time steps
# 10回連続成功
# 499 Episode: Finish after 200time steps
# 10回連続成功
# 500 Episode: Finish after 200time steps
# 10回連続成功
# 501 Episode: Finish after 200time steps
# 10回連続成功
# 502 Episode: Finish after 200time steps
# 10回連続成功
# 503 Episode: Finish after 200time steps
# 10回連続成功
# 504 Episode: Finish after 200time steps
# 10回連続成功
# 505 Episode: Finish after 200time steps
# 10回連続成功
# 506 Episode: Finish after 200time steps
# 10回連続成功
# 507 Episode: Finish after 200time steps
# 10回連続成功
# 508 Episode: Finish after 200time steps
# 10回連続成功
# 509 Episode: Finish after 200time steps
# 10回連続成功
# 510 Episode: Finish after 200time steps
# 10回連続成功
# 511 Episode: Finish after 200time steps
# 10回連続成功
# 512 Episode: Finish after 200time steps
# 10回連続成功
# 513 Episode: Finish after 200time steps
# 10回連続成功
# 514 Episode: Finish after 200time steps
# 10回連続成功
# 515 Episode: Finish after 200time steps
# 10回連続成功
# 516 Episode: Finish after 200time steps
# 10回連続成功
# 517 Episode: Finish after 200time steps
# 10回連続成功
# 518 Episode: Finish after 200time steps
# 10回連続成功
# 519 Episode: Finish after 200time steps
# 10回連続成功
# 520 Episode: Finish after 200time steps
# 10回連続成功
# 521 Episode: Finish after 200time steps
# 10回連続成功
# 522 Episode: Finish after 171time steps
# 523 Episode: Finish after 110time steps
# 524 Episode: Finish after 200time steps
# 525 Episode: Finish after 200time steps
# 526 Episode: Finish after 200time steps
# 527 Episode: Finish after 200time steps
# 528 Episode: Finish after 200time steps
# 529 Episode: Finish after 200time steps
# 530 Episode: Finish after 200time steps
# 531 Episode: Finish after 200time steps
# 532 Episode: Finish after 200time steps
# 533 Episode: Finish after 200time steps
# 10回連続成功
# 534 Episode: Finish after 200time steps
# 10回連続成功
# 535 Episode: Finish after 200time steps
# 10回連続成功
# 536 Episode: Finish after 200time steps
# 10回連続成功
# 537 Episode: Finish after 200time steps
# 10回連続成功
# 538 Episode: Finish after 200time steps
# 10回連続成功
# 539 Episode: Finish after 200time steps
# 10回連続成功
# 540 Episode: Finish after 200time steps
# 10回連続成功
# 541 Episode: Finish after 200time steps
# 10回連続成功
# 542 Episode: Finish after 200time steps
# 10回連続成功
# 543 Episode: Finish after 200time steps
# 10回連続成功
# 544 Episode: Finish after 200time steps
# 10回連続成功
# 545 Episode: Finish after 200time steps
# 10回連続成功
# 546 Episode: Finish after 200time steps
# 10回連続成功
# 547 Episode: Finish after 200time steps
# 10回連続成功
# 548 Episode: Finish after 200time steps
# 10回連続成功
# 549 Episode: Finish after 200time steps
# 10回連続成功
# 550 Episode: Finish after 200time steps
# 10回連続成功
# 551 Episode: Finish after 200time steps
# 10回連続成功
# 552 Episode: Finish after 200time steps
# 10回連続成功
# 553 Episode: Finish after 200time steps
# 10回連続成功
# 554 Episode: Finish after 200time steps
# 10回連続成功
# 555 Episode: Finish after 200time steps
# 10回連続成功
# 556 Episode: Finish after 200time steps
# 10回連続成功
# 557 Episode: Finish after 200time steps
# 10回連続成功
# 558 Episode: Finish after 200time steps
# 10回連続成功
# 559 Episode: Finish after 200time steps
# 10回連続成功
# 560 Episode: Finish after 200time steps
# 10回連続成功
# 561 Episode: Finish after 200time steps
# 10回連続成功
# 562 Episode: Finish after 200time steps
# 10回連続成功
# 563 Episode: Finish after 200time steps
# 10回連続成功
# 564 Episode: Finish after 200time steps
# 10回連続成功
# 565 Episode: Finish after 200time steps
# 10回連続成功
# 566 Episode: Finish after 200time steps
# 10回連続成功
# 567 Episode: Finish after 200time steps
# 10回連続成功
# 568 Episode: Finish after 200time steps
# 10回連続成功
# 569 Episode: Finish after 200time steps
# 10回連続成功
# 570 Episode: Finish after 200time steps
# 10回連続成功
# 571 Episode: Finish after 200time steps
# 10回連続成功
# 572 Episode: Finish after 200time steps
# 10回連続成功
# 573 Episode: Finish after 200time steps
# 10回連続成功
# 574 Episode: Finish after 200time steps
# 10回連続成功
# 575 Episode: Finish after 200time steps
# 10回連続成功
# 576 Episode: Finish after 200time steps
# 10回連続成功
# 577 Episode: Finish after 200time steps
# 10回連続成功
# 578 Episode: Finish after 200time steps
# 10回連続成功
# 579 Episode: Finish after 200time steps
# 10回連続成功
# 580 Episode: Finish after 200time steps
# 10回連続成功
# 581 Episode: Finish after 200time steps
# 10回連続成功
# 582 Episode: Finish after 200time steps
# 10回連続成功
# 583 Episode: Finish after 200time steps
# 10回連続成功
# 584 Episode: Finish after 200time steps
# 10回連続成功
# 585 Episode: Finish after 200time steps
# 10回連続成功
# 586 Episode: Finish after 200time steps
# 10回連続成功
# 587 Episode: Finish after 200time steps
# 10回連続成功
# 588 Episode: Finish after 200time steps
# 10回連続成功
# 589 Episode: Finish after 200time steps
# 10回連続成功
# 590 Episode: Finish after 200time steps
# 10回連続成功
# 591 Episode: Finish after 200time steps
# 10回連続成功
# 592 Episode: Finish after 200time steps
# 10回連続成功
# 593 Episode: Finish after 200time steps
# 10回連続成功
# 594 Episode: Finish after 200time steps
# 10回連続成功
# 595 Episode: Finish after 200time steps
# 10回連続成功
# 596 Episode: Finish after 200time steps
# 10回連続成功
# 597 Episode: Finish after 200time steps
# 10回連続成功
# 598 Episode: Finish after 200time steps
# 10回連続成功
# 599 Episode: Finish after 200time steps
# 10回連続成功
# 600 Episode: Finish after 200time steps
# 10回連続成功
# 601 Episode: Finish after 200time steps
# 10回連続成功
# 602 Episode: Finish after 200time steps
# 10回連続成功
# 603 Episode: Finish after 200time steps
# 10回連続成功
# 604 Episode: Finish after 200time steps
# 10回連続成功
# 605 Episode: Finish after 200time steps
# 10回連続成功
# 606 Episode: Finish after 200time steps
# 10回連続成功
# 607 Episode: Finish after 200time steps
# 10回連続成功
# 608 Episode: Finish after 200time steps
# 10回連続成功
# 609 Episode: Finish after 200time steps
# 10回連続成功
# 610 Episode: Finish after 200time steps
# 10回連続成功
# 611 Episode: Finish after 200time steps
# 10回連続成功
# 612 Episode: Finish after 200time steps
# 10回連続成功
# 613 Episode: Finish after 200time steps
# 10回連続成功
# 614 Episode: Finish after 200time steps
# 10回連続成功
# 615 Episode: Finish after 200time steps
# 10回連続成功
# 616 Episode: Finish after 200time steps
# 10回連続成功
# 617 Episode: Finish after 200time steps
# 10回連続成功
# 618 Episode: Finish after 200time steps
# 10回連続成功
# 619 Episode: Finish after 200time steps
# 10回連続成功
# 620 Episode: Finish after 200time steps
# 10回連続成功
# 621 Episode: Finish after 200time steps
# 10回連続成功
# 622 Episode: Finish after 200time steps
# 10回連続成功
# 623 Episode: Finish after 200time steps
# 10回連続成功
# 624 Episode: Finish after 200time steps
# 10回連続成功
# 625 Episode: Finish after 200time steps
# 10回連続成功
# 626 Episode: Finish after 200time steps
# 10回連続成功
# 627 Episode: Finish after 200time steps
# 10回連続成功
# 628 Episode: Finish after 200time steps
# 10回連続成功
# 629 Episode: Finish after 200time steps
# 10回連続成功
# 630 Episode: Finish after 200time steps
# 10回連続成功
# 631 Episode: Finish after 200time steps
# 10回連続成功
# 632 Episode: Finish after 200time steps
# 10回連続成功
# 633 Episode: Finish after 200time steps
# 10回連続成功
# 634 Episode: Finish after 200time steps
# 10回連続成功
# 635 Episode: Finish after 200time steps
# 10回連続成功
# 636 Episode: Finish after 200time steps
# 10回連続成功
# 637 Episode: Finish after 200time steps
# 10回連続成功
# 638 Episode: Finish after 200time steps
# 10回連続成功
# 639 Episode: Finish after 200time steps
# 10回連続成功
# 640 Episode: Finish after 200time steps
# 10回連続成功
# 641 Episode: Finish after 200time steps
# 10回連続成功
# 642 Episode: Finish after 200time steps
# 10回連続成功
# 643 Episode: Finish after 200time steps
# 10回連続成功
# 644 Episode: Finish after 200time steps
# 10回連続成功
# 645 Episode: Finish after 200time steps
# 10回連続成功
# 646 Episode: Finish after 200time steps
# 10回連続成功
# 647 Episode: Finish after 200time steps
# 10回連続成功
# 648 Episode: Finish after 200time steps
# 10回連続成功
# 649 Episode: Finish after 200time steps
# 10回連続成功
# 650 Episode: Finish after 200time steps
# 10回連続成功
# 651 Episode: Finish after 200time steps
# 10回連続成功
# 652 Episode: Finish after 200time steps
# 10回連続成功
# 653 Episode: Finish after 200time steps
# 10回連続成功
# 654 Episode: Finish after 200time steps
# 10回連続成功
# 655 Episode: Finish after 200time steps
# 10回連続成功
# 656 Episode: Finish after 200time steps
# 10回連続成功
# 657 Episode: Finish after 200time steps
# 10回連続成功
# 658 Episode: Finish after 200time steps
# 10回連続成功
# 659 Episode: Finish after 200time steps
# 10回連続成功
# 660 Episode: Finish after 200time steps
# 10回連続成功
# 661 Episode: Finish after 200time steps
# 10回連続成功
# 662 Episode: Finish after 200time steps
# 10回連続成功
# 663 Episode: Finish after 200time steps
# 10回連続成功
# 664 Episode: Finish after 200time steps
# 10回連続成功
# 665 Episode: Finish after 200time steps
# 10回連続成功
# 666 Episode: Finish after 200time steps
# 10回連続成功
# 667 Episode: Finish after 200time steps
# 10回連続成功
# 668 Episode: Finish after 200time steps
# 10回連続成功
# 669 Episode: Finish after 200time steps
# 10回連続成功
# 670 Episode: Finish after 200time steps
# 10回連続成功
# 671 Episode: Finish after 200time steps
# 10回連続成功
# 672 Episode: Finish after 200time steps
# 10回連続成功
# 673 Episode: Finish after 200time steps
# 10回連続成功
# 674 Episode: Finish after 200time steps
# 10回連続成功
# 675 Episode: Finish after 200time steps
# 10回連続成功
# 676 Episode: Finish after 200time steps
# 10回連続成功
# 677 Episode: Finish after 200time steps
# 10回連続成功
# 678 Episode: Finish after 200time steps
# 10回連続成功
# 679 Episode: Finish after 200time steps
# 10回連続成功
# 680 Episode: Finish after 200time steps
# 10回連続成功
# 681 Episode: Finish after 200time steps
# 10回連続成功
# 682 Episode: Finish after 200time steps
# 10回連続成功
# 683 Episode: Finish after 200time steps
# 10回連続成功
# 684 Episode: Finish after 200time steps
# 10回連続成功
# 685 Episode: Finish after 200time steps
# 10回連続成功
# 686 Episode: Finish after 200time steps
# 10回連続成功
# 687 Episode: Finish after 200time steps
# 10回連続成功
# 688 Episode: Finish after 200time steps
# 10回連続成功
# 689 Episode: Finish after 200time steps
# 10回連続成功
# 690 Episode: Finish after 200time steps
# 10回連続成功
# 691 Episode: Finish after 200time steps
# 10回連続成功
# 692 Episode: Finish after 200time steps
# 10回連続成功
# 693 Episode: Finish after 200time steps
# 10回連続成功
# 694 Episode: Finish after 200time steps
# 10回連続成功
# 695 Episode: Finish after 200time steps
# 10回連続成功
# 696 Episode: Finish after 200time steps
# 10回連続成功
# 697 Episode: Finish after 200time steps
# 10回連続成功
# 698 Episode: Finish after 200time steps
# 10回連続成功
# 699 Episode: Finish after 200time steps
# 10回連続成功
# 700 Episode: Finish after 200time steps
# 10回連続成功
# 701 Episode: Finish after 200time steps
# 10回連続成功
# 702 Episode: Finish after 200time steps
# 10回連続成功
# 703 Episode: Finish after 200time steps
# 10回連続成功
# 704 Episode: Finish after 200time steps
# 10回連続成功
# 705 Episode: Finish after 200time steps
# 10回連続成功
# 706 Episode: Finish after 200time steps
# 10回連続成功
# 707 Episode: Finish after 200time steps
# 10回連続成功
# 708 Episode: Finish after 200time steps
# 10回連続成功
# 709 Episode: Finish after 200time steps
# 10回連続成功
# 710 Episode: Finish after 200time steps
# 10回連続成功
# 711 Episode: Finish after 200time steps
# 10回連続成功
# 712 Episode: Finish after 200time steps
# 10回連続成功
# 713 Episode: Finish after 200time steps
# 10回連続成功
# 714 Episode: Finish after 200time steps
# 10回連続成功
# 715 Episode: Finish after 200time steps
# 10回連続成功
# 716 Episode: Finish after 200time steps
# 10回連続成功
# 717 Episode: Finish after 200time steps
# 10回連続成功
# 718 Episode: Finish after 200time steps
# 10回連続成功
# 719 Episode: Finish after 200time steps
# 10回連続成功
# 720 Episode: Finish after 200time steps
# 10回連続成功
# 721 Episode: Finish after 200time steps
# 10回連続成功
# 722 Episode: Finish after 200time steps
# 10回連続成功
# 723 Episode: Finish after 200time steps
# 10回連続成功
# 724 Episode: Finish after 200time steps
# 10回連続成功
# 725 Episode: Finish after 186time steps
# 726 Episode: Finish after 200time steps
# 727 Episode: Finish after 200time steps
# 728 Episode: Finish after 200time steps
# 729 Episode: Finish after 200time steps
# 730 Episode: Finish after 200time steps
# 731 Episode: Finish after 200time steps
# 732 Episode: Finish after 200time steps
# 733 Episode: Finish after 200time steps
# 734 Episode: Finish after 200time steps
# 735 Episode: Finish after 200time steps
# 10回連続成功
# 736 Episode: Finish after 200time steps
# 10回連続成功
# 737 Episode: Finish after 200time steps
# 10回連続成功
# 738 Episode: Finish after 200time steps
# 10回連続成功
# 739 Episode: Finish after 200time steps
# 10回連続成功
# 740 Episode: Finish after 200time steps
# 10回連続成功
# 741 Episode: Finish after 200time steps
# 10回連続成功
# 742 Episode: Finish after 200time steps
# 10回連続成功
# 743 Episode: Finish after 200time steps
# 10回連続成功
# 744 Episode: Finish after 200time steps
# 10回連続成功
# 745 Episode: Finish after 200time steps
# 10回連続成功
# 746 Episode: Finish after 200time steps
# 10回連続成功
# 747 Episode: Finish after 200time steps
# 10回連続成功
# 748 Episode: Finish after 200time steps
# 10回連続成功
# 749 Episode: Finish after 200time steps
# 10回連続成功
# 750 Episode: Finish after 200time steps
# 10回連続成功
# 751 Episode: Finish after 200time steps
# 10回連続成功
# 752 Episode: Finish after 200time steps
# 10回連続成功
# 753 Episode: Finish after 200time steps
# 10回連続成功
# 754 Episode: Finish after 200time steps
# 10回連続成功
# 755 Episode: Finish after 200time steps
# 10回連続成功
# 756 Episode: Finish after 200time steps
# 10回連続成功
# 757 Episode: Finish after 200time steps
# 10回連続成功
# 758 Episode: Finish after 200time steps
# 10回連続成功
# 759 Episode: Finish after 200time steps
# 10回連続成功
# 760 Episode: Finish after 200time steps
# 10回連続成功
# 761 Episode: Finish after 200time steps
# 10回連続成功
# 762 Episode: Finish after 200time steps
# 10回連続成功
# 763 Episode: Finish after 200time steps
# 10回連続成功
# 764 Episode: Finish after 200time steps
# 10回連続成功
# 765 Episode: Finish after 200time steps
# 10回連続成功
# 766 Episode: Finish after 200time steps
# 10回連続成功
# 767 Episode: Finish after 200time steps
# 10回連続成功
# 768 Episode: Finish after 200time steps
# 10回連続成功
# 769 Episode: Finish after 200time steps
# 10回連続成功
# 770 Episode: Finish after 200time steps
# 10回連続成功
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b5c44673166c> in <module>
#       1 #main
#       2 cartpole_env = Environment()
# ----> 3 cartpole_env.run()
#
# <ipython-input-22-d98460ba8a9f> in run(self)
#      39
#      40                 #Q関数を更新する
# ---> 41                 self.agent.update_Q_function(observation, action, reward, observation_next)
#      42
#      43                 #観測の更新
#
# <ipython-input-18-f6e607689f89> in update_Q_function(self, observation, action, reward, observation_next)
#       6     def update_Q_function(self, observation, action, reward, observation_next):
#       7         #Q関数の更新
# ----> 8         self.brain.update_Q_table(observation, action, reward, observation_next)
#       9
#      10     def get_action(self, observation, step):
#
# <ipython-input-19-b68f7f03c04b> in update_Q_table(self, observation, action, reward, observation_next)
#      26     def update_Q_table(self, observation, action, reward, observation_next):
#      27         #QテーブルをQ学習により更新
# ---> 28         state = self.digitize_state(observation) #状態を離散化
#      29         state_next = self.digitize_state(observation_next) #次の状態を離散化
#      30         Max_Q_next = max(self.q_table[state_next][:])
#
# <ipython-input-19-b68f7f03c04b> in digitize_state(self, observation)
#      18         digitized =[
#      19             np.digitize(cart_pos, bins=self.bins(-2.4, 2.4, NUM_DIZITIZED)),
# ---> 20             np.digitize(cart_v, bins=self.bins(-3.0, 3.0, NUM_DIZITIZED)),
#      21             np.digitize(pole_angle, bins=self.bins(-0.5, 0.5, NUM_DIZITIZED)),
#      22             np.digitize(pole_v, bins=self.bins(-2.0, 2.0, NUM_DIZITIZED))
#
# <ipython-input-19-b68f7f03c04b> in bins(self, clip_min, clip_max, num)
#      10     def bins(self,clip_min, clip_max, num):
#      11         #観測したデータを離散値にするしきい値を求める
# ---> 12         return np.linspace(clip_min, clip_max, num+1)[1:-1]
#      13
#      14     def digitize_state(self, observation):
#
# <__array_function__ internals> in linspace(*args, **kwargs)
#
# ~/.anyenv/envs/pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype, axis)
#     126
#     127     delta = stop - start
# --> 128     y = _nx.arange(0, num, dtype=dt).reshape((-1,) + (1,) * ndim(delta))
#     129     # In-place multiplication y *= delta/div is faster, but prevents the multiplicant
#     130     # from overriding what class is produced, and thus prevents, e.g. use of Quantities,
#
# KeyboardInterrupt:
